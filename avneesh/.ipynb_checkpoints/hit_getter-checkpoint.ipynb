# %%
import pandas as pd
# %run /Users/avneeshchandra/Cuttlefish/notebooks/users/avneesh/connect_to_api.ipynb

# %%
def get_hit(hit_type, hit_value, how_many = 10,sort_by = 'id'):
    """ 
    Get all retweets of a certain tweet ID between given dates
  
    Parameters: 
    feature (str): What type of hit to look for (retweets)
    rt_id (str): Tweet ID
    date_from (datetime): Datetime of when the tweet was made
    date_to (datetime): Datetime of when to check for retweeters till (a week after the tweet was made)
    
    Returns: 
    hits_df (DataFrame): Table with all retweets for a given tweet ID
  
    """

    query = "SELECT * FROM \
    \
    ( \
    SELECT \
    * \
    FROM \
    hits_twitter_{} \
    JOIN \
    map_nodes on map_nodes.node_id = hits_twitter_{}.node_id \
    WHERE \
    hits_twitter_{}.hit_value = '{}' \
    ) s \
    \
    LIMIT \
    {};;".format(hit_type, hit_type, hit_type, hit_value, how_many)
    
    r = cur.execute(query)
    hits = cur.fetchall()
    hits_df = pd.DataFrame(hits, columns=["id","hit_value", "node_id", "message_id","hit_time","params","id_2","node_id2","map_id","cluster_id"])
    
    hits_df["node_id"] = hits_df["node_id"].astype("str")
    hits_df["message_id"] = hits_df["message_id"].astype("str")
    hits_df["hit_type"] = hit_type
    hits_df.drop_duplicates([sort_by],inplace = True)
    
    clustername_values = hits_df.apply(clustername_lookup,axis = 1,result_type = 'reduce')
    hits_df.insert(loc = hits_df.shape[1]-1,column = 'cluster_name', value = clustername_values)
    
    hits_df.drop(columns = ['node_id2','id_2','id','params'],inplace = True)
    
    return hits_df.set_index(['hit_value'])

# %%
# hit_type = input('Hit type: ')
# hit_value = input('Hit value: ')

# %%
def clustername_lookup(rcvd_series):
    map_id = rcvd_series['map_id']
    cluster_id = rcvd_series['cluster_id']
    url = 'https://api.graphika.com/maps/{}/clusters/{}'.format(map_id,cluster_id)
    r = requests.get(url, auth = (username,pswd))
    try:
        return r.json()['name']
    except:
        return 'Map access needed'

# %%
# hits_to_check_dict = {'urls':['theringer.com'],'retweets':['1227561237782855680'],'hashtags':['MAGA'],'mentions':['1343351467']}

# results_dict = {'urls':{},'retweets':{},'hashtags':{},'mentions':{}}

# %%
# for hit_type in hits_to_check_dict.keys():
#     for hit_value in hits_to_check_dict[hit_type]:
# #         print('{}: {}'.format(hit_type,hit_value))
#         results_dict[hit_type][hit_value] = (get_hit(hit_type,hit_value,50,'map_id'))

# %%
# results_dict
# Out:
# {'urls': {'theringer.com':                 node_id          message_id            hit_time  map_id  \
#   hit_value
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    2279
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    2212
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1070
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02     666
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1267
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1441
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1217
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1236
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1238
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1292
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1052
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1746
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1809
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1812
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1914
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1671
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1100
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    1810
#   theringer.com  32765534  852532584261181441 2017-04-13 14:43:02    2048
#
#                  cluster_id hit_type
#   hit_value
#   theringer.com          17     urls
#   theringer.com          43     urls
#   theringer.com          23     urls
#   theringer.com          33     urls
#   theringer.com          57     urls
#   theringer.com           1     urls
#   theringer.com           7     urls
#   theringer.com          43     urls
#   theringer.com          35     urls
#   theringer.com          10     urls
#   theringer.com          15     urls
#   theringer.com          12     urls
#   theringer.com          42     urls
#   theringer.com          17     urls
#   theringer.com          11     urls
#   theringer.com          42     urls
#   theringer.com          42     urls
#   theringer.com          40     urls
#   theringer.com          37     urls  },
#  'retweets': {'1227561237782855680':                                 node_id           message_id  \
#   hit_value
#   1227561237782855680  797494558619828224  1227641015038857217
#   1227561237782855680  797494558619828224  1227641015038857217
#   1227561237782855680  797494558619828224  1227641015038857217
#   1227561237782855680 2020-02-12 17:03:02    2147          26  retweets
#   1227561237782855680 2020-02-12 17:03:02    2206          28  retweets  },
#  'hashtags': {'MAGA':                        node_id           message_id            hit_time  \
#   hit_value
#   MAGA                  44202015  1227640656543260672 2020-02-12 17:08:35
#   MAGA                  44202015  1227640656543260672 2020-02-12 17:08:35
#   MAGA                  44202015  1227640656543260672 2020-02-12 17:08:35
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA                  58505197  1227640506760429569 2020-02-12 17:07:59
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA        761303416782020608  1227640852744372225 2020-02-12 17:09:22
#   MAGA                1198296481  1227640315885936641 2020-02-12 17:07:14
#   MAGA                1198296481  1227640315885936641 2020-02-12 17:07:14
#   MAGA                1198296481  1227640315885936641 2020-02-12 17:07:14
#   MAGA                1198296481  1227640315885936641 2020-02-12 17:07:14
#   MAGA                1198296481  1227640315885936641 2020-02-12 17:07:14
#   MAGA       1127961179945676800  1227640386308497409 2020-02-12 17:07:31
#   MAGA       1127961179945676800  1227640386308497409 2020-02-12 17:07:31
#   MAGA       1127961179945676800  1227640386308497409 2020-02-12 17:07:31
#   MAGA       1127961179945676800  1227640386308497409 2020-02-12 17:07:31
#   MAGA       1127961179945676800  1227640386308497409 2020-02-12 17:07:31
#   MAGA       1127961179945676800  1227640386308497409 2020-02-12 17:07:31
#
#              map_id  cluster_id  hit_type
#   hit_value
#   MAGA         2311          26  hashtags
#   MAGA         2285           3  hashtags
#   MAGA         2284          19  hashtags
#   MAGA         1184           3  hashtags
#   MAGA         1369          16  hashtags
#   MAGA         1434          26  hashtags
#   MAGA         1422           3  hashtags
#   MAGA         1518           1  hashtags
#   MAGA         1594          27  hashtags
#   MAGA         1688           1  hashtags
#   MAGA         2018           4  hashtags
#   MAGA         2130          27  hashtags
#   MAGA         1342          42  hashtags
#   MAGA         1247          27  hashtags
#   MAGA         1302           1  hashtags
#   MAGA         1159           2  hashtags
#   MAGA         1488           4  hashtags
#   MAGA         1519           2  hashtags
#   MAGA         1520           3  hashtags
#   MAGA         1527           1  hashtags
#   MAGA         1955           1  hashtags
#   MAGA         1959           2  hashtags
#   MAGA         2046          43  hashtags
#   MAGA         2313          30  hashtags
#   MAGA         1834          16  hashtags
#   MAGA         1978          49  hashtags
#   MAGA         2028           6  hashtags
#   MAGA         2126          51  hashtags
#   MAGA         1831          16  hashtags
#   MAGA         1829          53  hashtags
#   MAGA         1911          27  hashtags
#   MAGA         1910          29  hashtags
#   MAGA         1943           6  hashtags
#   MAGA         2010          28  hashtags  },
#  'mentions': {'1343351467':                node_id           message_id            hit_time  map_id  \
#   hit_value
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    2284
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    2130
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    2277
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1434
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1422
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1487
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1518
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1594
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1657
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1688
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1838
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    1978
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    2018
#   1343351467  1343351467  1227539532146495489 2020-02-12 10:26:45    2011
#
#               cluster_id  hit_type
#   hit_value
#   1343351467          29  mentions
#   1343351467          36  mentions
#   1343351467          26  mentions
#   1343351467           1  mentions
#   1343351467           2  mentions
#   1343351467          28  mentions
#   1343351467           2  mentions
#   1343351467          42  mentions
#   1343351467          35  mentions
#   1343351467          23  mentions
#   1343351467           2  mentions
#   1343351467          28  mentions
#   1343351467          40  mentions
#   1343351467          56  mentions  }}

# %%
# # group influence: total map outdegs (excluding in group connections)
# # 4:07
# # group density: group connections/(n-1)^2
# # 4:07
# # analyst_tool.segment_stat (map_id = 100)

# node-level
#     get maps
#     get clusters
    
# map-level
#     group/cluster level
#         get influence
#         get connections
#             in
#             out
